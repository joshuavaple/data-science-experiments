# %%
# %pip install python-dotenv -q
# %restart_python

# %%
from databricks.sdk import WorkspaceClient
from dotenv import load_dotenv
import os


load_dotenv("./endpoint.env", override=True)
CLIENT_ID = os.environ.get("CLIENT_ID") # pre-created with UI
CLIENT_SECRET = os.environ.get("CLIENT_SECRET") # pre-created with UI
dbutils.widgets.text("secret_scope", "demo-scope") # pre-created before
SECRET_SCOPE = dbutils.widgets.get("secret_scope")

workspace = WorkspaceClient()
workspace.secrets.put_secret(SECRET_SCOPE, "accident_analysis_adb_llm_endpoint_client_id", string_value = CLIENT_ID)
workspace.secrets.put_secret(SECRET_SCOPE, "accident_analysis_adb_llm_endpoint_secret", string_value = CLIENT_SECRET)
