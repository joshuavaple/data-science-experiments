# %%
# %pip install python-dotenv -q
# %restart_python

# %%
from databricks.sdk import WorkspaceClient
from dotenv import load_dotenv
import os


load_dotenv("./env/gpt-oss-20b.env", override=True)
DATABRICKS_TOKEN = os.environ.get("DATABRICKS_TOKEN") # pre-created with UI

dbutils.widgets.text("secret_scope", "demo-scope") # pre-created before
SECRET_SCOPE = dbutils.widgets.get("secret_scope")

workspace = WorkspaceClient()
workspace.secrets.put_secret(SECRET_SCOPE, "gpt_oss_20b_databricks_token", string_value = DATABRICKS_TOKEN)
